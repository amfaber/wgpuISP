# %%
from importlib import reload
import load
reload(load)
from load import *
input = input.reshape(1080, 1920)
black_level = black_level.reshape(1080, 1920)
output = output.reshape(1080, 1920, 4)[:, :, :3].clip(0, 1023)
cfa = np.fromfile("cfa.bin", dtype = "uint16").reshape(1080, 1920, 3)
print(output.max())

# output /= output.max()
# Out:
# 1023.0

# %%
plt.imshow(cfa // 4)

# %%
plt.imshow(output[300:500, 300:500] / output.max())

# %%
plt.imshow(input[300:400, 300:400])

# %%
plt.imshow(cfa // 4)

# %%
plt.imshow(output)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(-(output[:, :, 0] - input))

# %%
slc = (slice(1050, None), slice(0, 100))

# %%
plt.imshow(output[*slc, 0] != input[slc])

# %%
bounds = slice(950, 1100)
plt.imshow(output[bounds, bounds])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(input[bounds, bounds])

# %%
plt.imshow(input[bounds, bounds] == output[bounds, bounds])

# %%
plt.imshow(input[bounds, bounds] == output.reshape(1080, 1920)[bounds, bounds])

# %%
plt.imshow(output)
